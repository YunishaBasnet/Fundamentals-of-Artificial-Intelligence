# %% [markdown]
# What Is the Average Height of US Presidents?
# Use file president_heights.csv, which is a comma-separated list of labels and values

# %% [markdown]
# ### Step1:
# Read the data with pandas, turn the 'height(cm)' column into a numpy array. Print the array.

# %%
import pandas as pd
data = pd.read_csv('president_heights.csv')

# %%
data.head()
# Out:
#    order               name  height(cm)
# 0      1  George Washington         189
# 1      2         John Adams         170
# 2      3   Thomas Jefferson         189
# 3      4      James Madison         163
# 4      5       James Monroe         183

# %%
import numpy as np
heights=np.array(data['height(cm)'])

# %% [markdown]
# ### Step2:
# - Print the mean of the heights
# - Print the standard deviatoin of heights
# - Print the minimum height
# - Print the maximum height

# %%
heights.mean()
# Out:
# 179.73809523809524

# %%
heights.std()
# Out:
# 6.931843442745892

# %%
heights.min()
# Out:
# 163

# %%
min(heights)
# Out:
# 163

# %%
heights.max()
# Out:
# 193

# %% [markdown]
# ### Step3:
# - Print the 25 percentile
# - Print the median of heights
# - Print the 75 percentile

# %%
np.percentile(heights, 25)
# Out:
# 174.25

# %%
np.percentile(heights,50)
# Out:
# 182.0

# %%
np.median(heights)
# Out:
# 182.0

# %%
np.percentile(heights,75)
# Out:
# 183.0

# %% [markdown]
# ### Step4:
# - Create a histogram of the heights
# - Give a title to the histogram
# - Give x and y labels

# %%
import matplotlib.pyplot as plt
plt.hist(heights)
plt.title('Height Distribution of US presidents')
plt.xlabel('height(cm)')
plt.ylabel('frequency');

# %% [markdown]
# ## Seattle Rainy Days

# %% [markdown]
# ### Step1:
# - Read the data with pandas, turn the 'date' column into date format and set the date as the index of the dataset
# - Select the precipitation column for year 2015 and assign it to a new variable
# - Create a histogram with title, y and x labels for the precipitation in year 2015. What do you observe?

# %%
import pandas as pd
raind = pd.read_csv('seattle_weather.csv')

# %%
raind.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
raind.shape
# Out:
# (1461, 6)

# %%
raind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1461 non-null   object
#  1   precipitation  1461 non-null   float64
#  2   temp_max       1461 non-null   float64
#  3   temp_min       1461 non-null   float64
#  4   wind           1461 non-null   float64
#  5   weather        1461 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 68.6+ KB

# %%
raind.iloc[0,0][0]
# Out:
# '2'

# %%
raind.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
raind['date']=pd.to_datetime(raind['date'],format ='%Y-%m-%d')

# %%
raind.head()
# Out:
#         date  precipitation  temp_max  temp_min  wind  weather
# 0 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2 2012-01-03            0.8      11.7       7.2   2.3     rain
# 3 2012-01-04           20.3      12.2       5.6   4.7     rain
# 4 2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
raind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1461 non-null   datetime64[ns]
#  1   precipitation  1461 non-null   float64
#  2   temp_max       1461 non-null   float64
#  3   temp_min       1461 non-null   float64
#  4   wind           1461 non-null   float64
#  5   weather        1461 non-null   object
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 68.6+ KB

# %%
raind.iloc[0,0].year
# Out:
# 2012

# %%
raind.set_index('date', inplace=True)

# %%
raind.head()
# Out:
#             precipitation  temp_max  temp_min  wind  weather
# date
# 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2012-01-03            0.8      11.7       7.2   2.3     rain
# 2012-01-04           20.3      12.2       5.6   4.7     rain
# 2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
raind['precipitation'] ['2012-01']
# Out:
# date
# 2012-01-01     0.0
# 2012-01-02    10.9
# 2012-01-03     0.8
# 2012-01-04    20.3
# 2012-01-05     1.3
# 2012-01-06     2.5
# 2012-01-07     0.0
# 2012-01-08     0.0
# 2012-01-09     4.3
# 2012-01-10     1.0
# 2012-01-11     0.0
# 2012-01-12     0.0
# 2012-01-13     0.0
# 2012-01-14     4.1
# 2012-01-15     5.3
# 2012-01-16     2.5
# 2012-01-17     8.1
# 2012-01-18    19.8
# 2012-01-19    15.2
# 2012-01-20    13.5
# 2012-01-21     3.0
# 2012-01-22     6.1
# 2012-01-23     0.0
# 2012-01-24     8.6
# 2012-01-25     8.1
# 2012-01-26     4.8
# 2012-01-27     0.0
# 2012-01-28     0.0
# 2012-01-29    27.7
# 2012-01-30     3.6
# 2012-01-31     1.8
# Name: precipitation, dtype: float64

# %%
raind.loc['2012-01']
# Out:
#             precipitation  temp_max  temp_min  wind  weather
# date
# 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2012-01-03            0.8      11.7       7.2   2.3     rain
# 2012-01-04           20.3      12.2       5.6   4.7     rain
# 2012-01-05            1.3       8.9       2.8   6.1     rain
# 2012-01-06            2.5       4.4       2.2   2.2     rain
# 2012-01-07            0.0       7.2       2.8   2.3     rain
# 2012-01-08            0.0      10.0       2.8   2.0      sun
# 2012-01-09            4.3       9.4       5.0   3.4     rain
# 2012-01-10            1.0       6.1       0.6   3.4     rain
# 2012-01-11            0.0       6.1      -1.1   5.1      sun
# 2012-01-12            0.0       6.1      -1.7   1.9      sun
# 2012-01-13            0.0       5.0      -2.8   1.3      sun
# 2012-01-14            4.1       4.4       0.6   5.3     snow
# 2012-01-15            5.3       1.1      -3.3   3.2     snow
# 2012-01-16            2.5       1.7      -2.8   5.0     snow
# 2012-01-17            8.1       3.3       0.0   5.6     snow
# 2012-01-18           19.8       0.0      -2.8   5.0     snow
# 2012-01-19           15.2      -1.1      -2.8   1.6     snow
# 2012-01-20           13.5       7.2      -1.1   2.3     snow
# 2012-01-21            3.0       8.3       3.3   8.2     rain
# 2012-01-22            6.1       6.7       2.2   4.8     rain
# 2012-01-23            0.0       8.3       1.1   3.6     rain
# 2012-01-24            8.6      10.0       2.2   5.1     rain
# 2012-01-25            8.1       8.9       4.4   5.4     rain
# 2012-01-26            4.8       8.9       1.1   4.8     rain
# 2012-01-27            0.0       6.7      -2.2   1.4  drizzle
# 2012-01-28            0.0       6.7       0.6   2.2     rain
# 2012-01-29           27.7       9.4       3.9   4.5     rain
# 2012-01-30            3.6       8.3       6.1   5.1     rain
# 2012-01-31            1.8       9.4       6.1   3.9     rain

# %%
rainfall_15= raind['precipitation']['2015']

# %%
plt.hist(rainfall_15);

# %% [markdown]
# ### Step2:
# - construct a mask of all rainy days
# - construct a mask of all summer days (June 21st is the 172nd day)
# - print the median precip on rainy days in 2015
# - print the median precip on summer days in 2015
# - print the m

# %%
rainy =(rainfall_15>0)

# %%
June 21st:172nd day-September 21:264th day

# %%
raind.loc['2012-01-01':'2012-09-21'].shape
# Out:
# (265, 5)

# %%
days =np.arange(365)

# %%
summer=(days >172)&(days<263)

# %%
rainy, summer

# %%
rainy
# Out:
# date
# 2015-01-01    False
# 2015-01-02     True
# 2015-01-03    False
# 2015-01-04     True
# 2015-01-05     True
#               ...
# 2015-12-27     True
# 2015-12-28     True
# 2015-12-29    False
# 2015-12-30    False
# 2015-12-31    False
# Name: precipitation, Length: 365, dtype: bool

# %%
np.median(rainfall_15[rainy])
# Out:
# 3.8

# %%
np.median(rainfall_15[summer])
# Out:
# 0.0

# %%
np.max(rainfall_15[summer])
# Out:
# 32.5

# %%
(~summer)& rainy
# Out:
# date
# 2015-01-01    False
# 2015-01-02     True
# 2015-01-03    False
# 2015-01-04     True
# 2015-01-05     True
#               ...
# 2015-12-27     True
# 2015-12-28     True
# 2015-12-29    False
# 2015-12-30    False
# 2015-12-31    False
# Name: precipitation, Length: 365, dtype: bool

# %%
np.median(rainfall_15[ rainy & (~summer) ])
# Out:
# 4.1
